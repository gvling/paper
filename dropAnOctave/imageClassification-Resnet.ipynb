# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from datetime import datetime, timedelta, timezone

import sys
sys.path.append('../')
from utils import data
from models.resnet import Resnet18  as Resnet
from utils.visualization import *

# %%
bn = False
# const
taskName = 'fasionClassfiction'
modelName = 'resnet{}'.format('_bn' if bn else '')
JST = timezone(timedelta(hours=+9), 'JST')
now = datetime.now(JST)
nowStr = now.strftime("%Y%m%d_%H%M%S")
showImgCount = 10

imgHeight = 224
imgWidth = 224
imgChannel = 3
imgShape = [-1, imgHeight, imgWidth, imgChannel]
labelSize = 13
tfrecordPath = './img/fashionDataset/tfrecord/dataset224.tfrecord'
trainRatio = 0.7

# hyper parameter
bs = 32
lr = 0.000002
ep = 50

logDir = '../logs/{}/{}/{}/'.format(taskName, modelName, nowStr)
metadataDir = '{}metadata.tsv'.format(logDir)
checkPointDir = '{}images.ckpt'.format(logDir)

# %%
# main
with tf.Graph().as_default():
    # load data
    with tf.variable_scope('tfrecord'):
        tfrecord = data.TFRecord(tfrecordPath, labelSize)
        dataset = tfrecord.toDataset()
        # split dataset
        tfrecord = data.TFRecord(tfrecordPath, labelSize)
        dataset = tfrecord.toDataset()
        trainSize, testSize, trainDataset, testDataset = tfrecord.splitDataset(bs, trainRatio)
        trainIteration = trainSize // bs
        testIteration = testSize // bs        
        # TODO: data augmentation

    # make iterator
    with tf.variable_scope('train_data'):
        trainIterator = trainDataset.make_initializable_iterator()
        trainNextBatch = trainIterator.get_next(name='train_next_batch')
        trainIteratorInitOp = trainIterator.initializer
    with tf.variable_scope('test_data'):
        testIterator = testDataset.make_initializable_iterator()
        testNextBatch = testIterator.get_next(name='test_next_batch')
        testIteratorInitOp = testIterator.initializer

    
    x = tf.placeholder("float", [None, imgHeight, imgWidth, imgChannel], name='x')
    y = tf.placeholder("float", [None, labelSize], name='label')
    isTrain = tf.placeholder(tf.bool, name='is_train')
    
    network = Resnet(x, labelSize=labelSize, batchNorm=bn, visualization=True)
    _ = network.inference(isTrain)
    cost = network.loss(y)
    optimizer = tf.train.AdamOptimizer(lr)
    accuracy = network.accuracy(y)
    trainOp = network.training(cost, optimizer)
    drawHist = tf.summary.merge_all('histogram')
    
    saver = tf.train.Saver()
    config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True))
    sess = tf.Session(config=config)
    summaryWriter = tf.summary.FileWriter(logDir, graph=sess.graph)
    sess.run(tf.global_variables_initializer())
    # Training cycle
    for e in range(ep):
        trainAvgAcc = trainAvgLoss = testAvgAcc = testAvgLoss = 0.
        # train
        sess.run(trainIteratorInitOp)
        for i in range(trainIteration):
            _, batchX, batchY = sess.run(trainNextBatch)
            _, l, a = sess.run([trainOp, cost, accuracy], feed_dict={x: batchX, y: batchY, isTrain: True})
            trainAvgAcc += a / trainIteration
            trainAvgLoss += l / trainIteration

        # validation
        sess.run(testIteratorInitOp)
        for i in range(testIteration):
            _, testBatchX, testBatchY = sess.run(testNextBatch)
            l, a, histogram = sess.run([cost, accuracy, drawHist], feed_dict={x: testBatchX, y: testBatchY, isTrain: False})
            testAvgAcc += a / testIteration
            testAvgLoss += l / testIteration

        # tensorBoard
        summaryWriter.add_summary(drawSclar('train', {'acc': trainAvgAcc, 'loss': trainAvgLoss}), global_step=e)
        summaryWriter.add_summary(drawSclar('validation', {'acc': testAvgAcc, 'loss': testAvgLoss}), global_step=e)
        summaryWriter.add_summary(histogram, global_step=e)
        saver.save(sess, checkPointDir, global_step=e)
        print('Epoch: {} | Train Accuracy: {:.4f} | Train Loss: {:.4f} | Test Accuracy: {:.4f} | Test Loss: {:.4f}'.format(e, trainAvgAcc, trainAvgLoss, testAvgAcc, testAvgLoss))
    summaryWriter.close()
    sess.close()
# Out:
# Epoch: 0 | Train Accuracy: 0.0478 | Train Loss: 2.6412 | Test Accuracy: 0.0473 | Test Loss: 2.6418
# Epoch: 1 | Train Accuracy: 0.0473 | Train Loss: 2.6418 | Test Accuracy: 0.0505 | Test Loss: 2.6386
# Epoch: 2 | Train Accuracy: 0.0480 | Train Loss: 2.6411 | Test Accuracy: 0.0438 | Test Loss: 2.6453
# Epoch: 3 | Train Accuracy: 0.0490 | Train Loss: 2.6401 | Test Accuracy: 0.0462 | Test Loss: 2.6429
# Epoch: 4 | Train Accuracy: 0.0475 | Train Loss: 2.6416 | Test Accuracy: 0.0472 | Test Loss: 2.6419
# Epoch: 5 | Train Accuracy: 0.0477 | Train Loss: 2.6414 | Test Accuracy: 0.0485 | Test Loss: 2.6406
# Epoch: 6 | Train Accuracy: 0.0473 | Train Loss: 2.6418 | Test Accuracy: 0.0445 | Test Loss: 2.6446
# Epoch: 7 | Train Accuracy: 0.0483 | Train Loss: 2.6408 | Test Accuracy: 0.0480 | Test Loss: 2.6411
# Epoch: 8 | Train Accuracy: 0.0464 | Train Loss: 2.6427 | Test Accuracy: 0.0480 | Test Loss: 2.6411
# Epoch: 9 | Train Accuracy: 0.0467 | Train Loss: 2.6424 | Test Accuracy: 0.0485 | Test Loss: 2.6406
# Epoch: 10 | Train Accuracy: 0.0496 | Train Loss: 2.6395 | Test Accuracy: 0.0484 | Test Loss: 2.6407
# Epoch: 11 | Train Accuracy: 0.0470 | Train Loss: 2.6421 | Test Accuracy: 0.0464 | Test Loss: 2.6427
# Epoch: 12 | Train Accuracy: 0.0480 | Train Loss: 2.6411 | Test Accuracy: 0.0471 | Test Loss: 2.6420
# Epoch: 13 | Train Accuracy: 0.0475 | Train Loss: 2.6416 | Test Accuracy: 0.0497 | Test Loss: 2.6394
# Epoch: 14 | Train Accuracy: 0.0477 | Train Loss: 2.6413 | Test Accuracy: 0.0489 | Test Loss: 2.6402
# Epoch: 15 | Train Accuracy: 0.0476 | Train Loss: 2.6415 | Test Accuracy: 0.0488 | Test Loss: 2.6403
# Epoch: 16 | Train Accuracy: 0.0489 | Train Loss: 2.6402 | Test Accuracy: 0.0497 | Test Loss: 2.6394
# Epoch: 17 | Train Accuracy: 0.0466 | Train Loss: 2.6425 | Test Accuracy: 0.0496 | Test Loss: 2.6395
# Epoch: 18 | Train Accuracy: 0.0477 | Train Loss: 2.6414 | Test Accuracy: 0.0493 | Test Loss: 2.6398
# Epoch: 19 | Train Accuracy: 0.3233 | Train Loss: 2.3657 | Test Accuracy: 0.3944 | Test Loss: 2.2947
# Epoch: 20 | Train Accuracy: 0.3872 | Train Loss: 2.3019 | Test Accuracy: 0.3889 | Test Loss: 2.3002
# Epoch: 21 | Train Accuracy: 0.3891 | Train Loss: 2.2999 | Test Accuracy: 0.3917 | Test Loss: 2.2974
# Epoch: 22 | Train Accuracy: 0.3899 | Train Loss: 2.2992 | Test Accuracy: 0.3832 | Test Loss: 2.3059
# Epoch: 23 | Train Accuracy: 0.3869 | Train Loss: 2.3022 | Test Accuracy: 0.3889 | Test Loss: 2.3002
# Epoch: 24 | Train Accuracy: 0.3877 | Train Loss: 2.3013 | Test Accuracy: 0.3903 | Test Loss: 2.2988
# Epoch: 25 | Train Accuracy: 0.3883 | Train Loss: 2.3008 | Test Accuracy: 0.3887 | Test Loss: 2.3004
# Epoch: 26 | Train Accuracy: 0.3881 | Train Loss: 2.3010 | Test Accuracy: 0.3832 | Test Loss: 2.3059
# Epoch: 27 | Train Accuracy: 0.3863 | Train Loss: 2.3028 | Test Accuracy: 0.3951 | Test Loss: 2.2940
# Epoch: 28 | Train Accuracy: 0.3872 | Train Loss: 2.3019 | Test Accuracy: 0.3823 | Test Loss: 2.3068
# Epoch: 29 | Train Accuracy: 0.3858 | Train Loss: 2.3032 | Test Accuracy: 0.3928 | Test Loss: 2.2963
# Epoch: 30 | Train Accuracy: 0.3857 | Train Loss: 2.3034 | Test Accuracy: 0.3895 | Test Loss: 2.2996
# Epoch: 31 | Train Accuracy: 0.3847 | Train Loss: 2.3044 | Test Accuracy: 0.3819 | Test Loss: 2.3072
# Epoch: 32 | Train Accuracy: 0.3855 | Train Loss: 2.3036 | Test Accuracy: 0.3862 | Test Loss: 2.3028
# Epoch: 33 | Train Accuracy: 0.3877 | Train Loss: 2.3013 | Test Accuracy: 0.3949 | Test Loss: 2.2942
# Epoch: 34 | Train Accuracy: 0.3871 | Train Loss: 2.3020 | Test Accuracy: 0.3839 | Test Loss: 2.3052
# Epoch: 35 | Train Accuracy: 0.3862 | Train Loss: 2.3029 | Test Accuracy: 0.3898 | Test Loss: 2.2993
# Epoch: 36 | Train Accuracy: 0.3867 | Train Loss: 2.3024 | Test Accuracy: 0.3810 | Test Loss: 2.3081
# Epoch: 37 | Train Accuracy: 0.3866 | Train Loss: 2.3025 | Test Accuracy: 0.3802 | Test Loss: 2.3089
# Epoch: 38 | Train Accuracy: 0.3880 | Train Loss: 2.3011 | Test Accuracy: 0.3852 | Test Loss: 2.3039
# Epoch: 39 | Train Accuracy: 0.3905 | Train Loss: 2.2986 | Test Accuracy: 0.3859 | Test Loss: 2.3032
# Epoch: 40 | Train Accuracy: 0.3854 | Train Loss: 2.3037 | Test Accuracy: 0.3856 | Test Loss: 2.3035
# Epoch: 41 | Train Accuracy: 0.3892 | Train Loss: 2.2999 | Test Accuracy: 0.3898 | Test Loss: 2.2993
# Epoch: 42 | Train Accuracy: 0.3901 | Train Loss: 2.2990 | Test Accuracy: 0.3898 | Test Loss: 2.2993
# Epoch: 43 | Train Accuracy: 0.3948 | Train Loss: 2.2943 | Test Accuracy: 0.3856 | Test Loss: 2.3035
# Epoch: 44 | Train Accuracy: 0.3845 | Train Loss: 2.3046 | Test Accuracy: 0.3834 | Test Loss: 2.3057
# Epoch: 45 | Train Accuracy: 0.3892 | Train Loss: 2.2999 | Test Accuracy: 0.3857 | Test Loss: 2.3034
# Epoch: 46 | Train Accuracy: 0.3855 | Train Loss: 2.3036 | Test Accuracy: 0.3953 | Test Loss: 2.2938
# Epoch: 47 | Train Accuracy: 0.3853 | Train Loss: 2.3037 | Test Accuracy: 0.3902 | Test Loss: 2.2989
# Epoch: 48 | Train Accuracy: 0.3857 | Train Loss: 2.3034 | Test Accuracy: 0.3845 | Test Loss: 2.3045
# Epoch: 49 | Train Accuracy: 0.3852 | Train Loss: 2.3039 | Test Accuracy: 0.3815 | Test Loss: 2.3076
