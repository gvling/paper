# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from datetime import datetime, timedelta, timezone

import sys
sys.path.append('../')
from utils import data
from models import lenetOctave
from utils import visualization

# %%
# const
name = 'fasionClassfictionOctConv'
JST = timezone(timedelta(hours=+9), 'JST')
now = datetime.now(JST)
nowStr = now.strftime("%Y%m%d_%H%M%S")
showImgCount = 10

imgHeight = 224
imgWidth = 224
imgChannel = 3
imgShape = [-1, imgHeight, imgWidth, imgChannel]
labelSize = 13
tfrecordPath = './img/fashionDataset/tfrecord/dataset224.tfrecord'
trainRatio = 0.7

# hyper parameter
bs = 32
lr = 0.0001
ep = 100

# low channel ratio
alpha = 0.25

logDir = '../logs/{}/{}/'.format(name, nowStr)
metadataDir = '{}metadata.tsv'.format(logDir)
checkPointDir = '{}images.ckpt'.format(logDir)

# %%
# main
with tf.Graph().as_default():
    # load data
    with tf.variable_scope('tfrecord'):
        tfrecord = data.TFRecord(tfrecordPath, labelSize)
        dataset = tfrecord.toDataset()
        # split dataset
        tfrecord = data.TFRecord(tfrecordPath, labelSize)
        dataset = tfrecord.toDataset()
        trainSize, testSize, trainDataset, testDataset = tfrecord.splitDataset(bs)
        trainIteration = trainSize // bs
        testIteration = testSize // bs        
        # TODO: data augmentation

    # make iterator
    with tf.variable_scope('train_data'):
        trainIterator = trainDataset.make_initializable_iterator()
        trainNextBatch = trainIterator.get_next(name='train_next_batch')
        trainIteratorInitOp = trainIterator.initializer
    with tf.variable_scope('test_data'):
        testIterator = testDataset.make_initializable_iterator()
        testNextBatch = testIterator.get_next(name='test_next_batch')
        testIteratorInitOp = testIterator.initializer

    
    x = tf.placeholder("float", [None, imgHeight, imgWidth, imgChannel], name='x')
    y = tf.placeholder("float", [None, labelSize], name='label')

    lenet = lenetOctave.Lenet(alpha, x, inputShape=imgShape, labelSize=labelSize)
    cost = lenet.loss(y)
    optimizer = tf.train.AdamOptimizer(lr)
    accuracy = lenet.accuracy(y)
    trainOp = lenet.training(cost, optimizer)

    # tensor board
    with tf.variable_scope('train'):
        drawTrainAcc = tf.summary.scalar('acc', accuracy)
        drawTrainLoss = tf.summary.scalar('loss', cost)
        trainSummaryOp = tf.summary.merge([drawTrainAcc, drawTrainLoss])
    with tf.variable_scope("validation"):
        drawValAcc = tf.summary.scalar('acc', accuracy)
        drawValLoss = tf.summary.scalar('loss', cost)
        valSummaryOp = tf.summary.merge([drawValAcc, drawValLoss])
    
    drawImage = tf.summary.image('train_images', tf.reshape(x, imgShape), showImgCount)
    allVariables = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
    summaryOp = tf.summary.merge([drawImage])
    
    saver = tf.train.Saver()
    sess = tf.Session()
    summaryWriter = tf.summary.FileWriter(logDir, graph=sess.graph)

    sess.run(tf.global_variables_initializer())

    # Training cycle
    for e in range(ep):
        # train
        sess.run(trainIteratorInitOp)
        for i in range(trainIteration):
            _, batchX, batchY = sess.run(trainNextBatch)
            sess.run(trainOp, feed_dict={x: batchX, y: batchY})
        # Display logs per epoch step
        # TODO: coculate avg
        trainSummary = sess.run([trainSummaryOp,summaryOp], feed_dict={x: batchX, y: batchY})
        for summary in trainSummary:
            summaryWriter.add_summary(summary, e)
        # validation
        sess.run(testIteratorInitOp)
        for i in range(testIteration):
            _, testBatchX, testBatchY = sess.run(testNextBatch)
            sess.run([cost, accuracy], feed_dict={x: testBatchX, y: testBatchY})
        # TODO: coculate avg
        valSummary = sess.run([valSummaryOp], feed_dict={x: testBatchX, y: testBatchY})
        for summary in valSummary:
            summaryWriter.add_summary(summary, e)
            
        saver.save(sess, checkPointDir, global_step=e)
        trainAcc = sess.run(accuracy, feed_dict={x: batchX, y: batchY})
        valAcc = sess.run(accuracy, feed_dict={x: testBatchX, y: testBatchY})
        print('Epoch: {} | Train Accuracy: {} | Validation Accuracy: {}'.format(e, trainAcc, valAcc))
    summaryWriter.close()
    sess.close()
# Out:
# Epoch: 0 | Train Accuracy: 0.3125 | Validation Accuracy: 0.40625
# Epoch: 1 | Train Accuracy: 0.25 | Validation Accuracy: 0.5
# Epoch: 2 | Train Accuracy: 0.28125 | Validation Accuracy: 0.46875
# Epoch: 3 | Train Accuracy: 0.5 | Validation Accuracy: 0.40625
# Epoch: 4 | Train Accuracy: 0.34375 | Validation Accuracy: 0.5
# Epoch: 5 | Train Accuracy: 0.40625 | Validation Accuracy: 0.4375
# Epoch: 6 | Train Accuracy: 0.40625 | Validation Accuracy: 0.375
# Epoch: 7 | Train Accuracy: 0.40625 | Validation Accuracy: 0.25
# Epoch: 8 | Train Accuracy: 0.28125 | Validation Accuracy: 0.375
# Epoch: 9 | Train Accuracy: 0.28125 | Validation Accuracy: 0.34375
# Epoch: 10 | Train Accuracy: 0.40625 | Validation Accuracy: 0.46875
# Epoch: 11 | Train Accuracy: 0.40625 | Validation Accuracy: 0.53125
# Epoch: 12 | Train Accuracy: 0.3125 | Validation Accuracy: 0.40625
# Epoch: 13 | Train Accuracy: 0.4375 | Validation Accuracy: 0.4375
# Epoch: 14 | Train Accuracy: 0.5 | Validation Accuracy: 0.25
# Epoch: 15 | Train Accuracy: 0.3125 | Validation Accuracy: 0.40625
# Epoch: 16 | Train Accuracy: 0.40625 | Validation Accuracy: 0.375
# Epoch: 17 | Train Accuracy: 0.34375 | Validation Accuracy: 0.3125
# Epoch: 18 | Train Accuracy: 0.3125 | Validation Accuracy: 0.4375
# Epoch: 19 | Train Accuracy: 0.25 | Validation Accuracy: 0.34375
# Epoch: 20 | Train Accuracy: 0.40625 | Validation Accuracy: 0.40625
# Epoch: 21 | Train Accuracy: 0.40625 | Validation Accuracy: 0.34375
# Epoch: 22 | Train Accuracy: 0.25 | Validation Accuracy: 0.3125
# Epoch: 23 | Train Accuracy: 0.375 | Validation Accuracy: 0.28125
# Epoch: 24 | Train Accuracy: 0.375 | Validation Accuracy: 0.34375
# Epoch: 25 | Train Accuracy: 0.34375 | Validation Accuracy: 0.4375
# Epoch: 26 | Train Accuracy: 0.21875 | Validation Accuracy: 0.34375
# Epoch: 27 | Train Accuracy: 0.3125 | Validation Accuracy: 0.5
# Epoch: 28 | Train Accuracy: 0.34375 | Validation Accuracy: 0.40625
# Epoch: 29 | Train Accuracy: 0.40625 | Validation Accuracy: 0.375
# Epoch: 30 | Train Accuracy: 0.4375 | Validation Accuracy: 0.34375
# Epoch: 31 | Train Accuracy: 0.40625 | Validation Accuracy: 0.21875
# Epoch: 32 | Train Accuracy: 0.46875 | Validation Accuracy: 0.40625
# Epoch: 33 | Train Accuracy: 0.5 | Validation Accuracy: 0.3125
# Epoch: 34 | Train Accuracy: 0.40625 | Validation Accuracy: 0.4375
# Epoch: 35 | Train Accuracy: 0.40625 | Validation Accuracy: 0.59375
# Epoch: 36 | Train Accuracy: 0.4375 | Validation Accuracy: 0.40625
# Epoch: 37 | Train Accuracy: 0.3125 | Validation Accuracy: 0.40625
# Epoch: 38 | Train Accuracy: 0.40625 | Validation Accuracy: 0.46875
# Epoch: 39 | Train Accuracy: 0.3125 | Validation Accuracy: 0.28125
# Epoch: 40 | Train Accuracy: 0.59375 | Validation Accuracy: 0.34375
# Epoch: 41 | Train Accuracy: 0.28125 | Validation Accuracy: 0.40625
# Epoch: 42 | Train Accuracy: 0.46875 | Validation Accuracy: 0.3125
# Epoch: 43 | Train Accuracy: 0.4375 | Validation Accuracy: 0.3125
# Epoch: 44 | Train Accuracy: 0.46875 | Validation Accuracy: 0.28125
# Epoch: 45 | Train Accuracy: 0.4375 | Validation Accuracy: 0.375
# Epoch: 46 | Train Accuracy: 0.46875 | Validation Accuracy: 0.40625
# Epoch: 47 | Train Accuracy: 0.21875 | Validation Accuracy: 0.21875
# Epoch: 48 | Train Accuracy: 0.375 | Validation Accuracy: 0.25
# Epoch: 49 | Train Accuracy: 0.3125 | Validation Accuracy: 0.40625
# Epoch: 50 | Train Accuracy: 0.28125 | Validation Accuracy: 0.28125
# Epoch: 51 | Train Accuracy: 0.34375 | Validation Accuracy: 0.34375
# Epoch: 52 | Train Accuracy: 0.1875 | Validation Accuracy: 0.3125
# Epoch: 53 | Train Accuracy: 0.4375 | Validation Accuracy: 0.25
# Epoch: 54 | Train Accuracy: 0.625 | Validation Accuracy: 0.40625
# Epoch: 55 | Train Accuracy: 0.34375 | Validation Accuracy: 0.4375
# Epoch: 56 | Train Accuracy: 0.40625 | Validation Accuracy: 0.34375
# Epoch: 57 | Train Accuracy: 0.46875 | Validation Accuracy: 0.40625
# Epoch: 58 | Train Accuracy: 0.28125 | Validation Accuracy: 0.375
# Epoch: 59 | Train Accuracy: 0.4375 | Validation Accuracy: 0.25
# Epoch: 60 | Train Accuracy: 0.375 | Validation Accuracy: 0.4375
# Epoch: 61 | Train Accuracy: 0.5625 | Validation Accuracy: 0.34375
# Epoch: 62 | Train Accuracy: 0.34375 | Validation Accuracy: 0.1875
# Epoch: 63 | Train Accuracy: 0.34375 | Validation Accuracy: 0.4375
# Epoch: 64 | Train Accuracy: 0.375 | Validation Accuracy: 0.4375
# Epoch: 65 | Train Accuracy: 0.28125 | Validation Accuracy: 0.375
# Epoch: 66 | Train Accuracy: 0.28125 | Validation Accuracy: 0.46875
# Epoch: 67 | Train Accuracy: 0.375 | Validation Accuracy: 0.4375
# Epoch: 68 | Train Accuracy: 0.375 | Validation Accuracy: 0.4375
# Epoch: 69 | Train Accuracy: 0.4375 | Validation Accuracy: 0.3125
# Epoch: 70 | Train Accuracy: 0.28125 | Validation Accuracy: 0.3125
# Epoch: 71 | Train Accuracy: 0.375 | Validation Accuracy: 0.46875
# Epoch: 72 | Train Accuracy: 0.34375 | Validation Accuracy: 0.4375
# Epoch: 73 | Train Accuracy: 0.3125 | Validation Accuracy: 0.4375
# Epoch: 74 | Train Accuracy: 0.28125 | Validation Accuracy: 0.4375
# Epoch: 75 | Train Accuracy: 0.3125 | Validation Accuracy: 0.3125
# Epoch: 76 | Train Accuracy: 0.34375 | Validation Accuracy: 0.375
# Epoch: 77 | Train Accuracy: 0.5625 | Validation Accuracy: 0.21875
# Epoch: 78 | Train Accuracy: 0.4375 | Validation Accuracy: 0.46875
# Epoch: 79 | Train Accuracy: 0.40625 | Validation Accuracy: 0.59375
# Epoch: 80 | Train Accuracy: 0.46875 | Validation Accuracy: 0.40625
# Epoch: 81 | Train Accuracy: 0.5 | Validation Accuracy: 0.46875
# Epoch: 82 | Train Accuracy: 0.375 | Validation Accuracy: 0.375
# Epoch: 83 | Train Accuracy: 0.34375 | Validation Accuracy: 0.46875
# Epoch: 84 | Train Accuracy: 0.5 | Validation Accuracy: 0.3125
# Epoch: 85 | Train Accuracy: 0.34375 | Validation Accuracy: 0.53125
# Epoch: 86 | Train Accuracy: 0.5 | Validation Accuracy: 0.4375
# Epoch: 87 | Train Accuracy: 0.21875 | Validation Accuracy: 0.40625
# Epoch: 88 | Train Accuracy: 0.4375 | Validation Accuracy: 0.375
# Epoch: 89 | Train Accuracy: 0.34375 | Validation Accuracy: 0.28125
# Epoch: 90 | Train Accuracy: 0.28125 | Validation Accuracy: 0.25
# Epoch: 91 | Train Accuracy: 0.375 | Validation Accuracy: 0.4375
# Epoch: 92 | Train Accuracy: 0.40625 | Validation Accuracy: 0.15625
# Epoch: 93 | Train Accuracy: 0.34375 | Validation Accuracy: 0.4375
# Epoch: 94 | Train Accuracy: 0.375 | Validation Accuracy: 0.21875
# Epoch: 95 | Train Accuracy: 0.40625 | Validation Accuracy: 0.5
# Epoch: 96 | Train Accuracy: 0.34375 | Validation Accuracy: 0.28125
# Epoch: 97 | Train Accuracy: 0.375 | Validation Accuracy: 0.40625
# Epoch: 98 | Train Accuracy: 0.46875 | Validation Accuracy: 0.21875
# Epoch: 99 | Train Accuracy: 0.40625 | Validation Accuracy: 0.1875
